# %% [markdown]
# ## Limit of a Function

# %% [markdown]
# <p>In this independent work, you are going to analyze one of the indeterminate form
# $1^ \infty $ </p>

# %%
import sympy as sym
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sympy.abc import x

# %% [markdown]
# ## Task 1:
# <p><ul>
# <li> Find a rational function $f(x)$ such that <br> $\lim_{x \to 0} f(x) = 0$ </li>
# <li> Show that the limit is 0 (by making a table of values) and using sympy.limit</li>
# <li> Draw the graph of the function in the interval $[-3,3]$ </li></ul></p>

# %%
fs = sym.sympify("x/(x*(x+1))-1")
fsl = sym.lambdify(x, fs)
x_values = np.linspace(-3, 3, 500)
# y_values = fsl(x_values)

# %%
for i in x_values:
    print(i, fsl(i))
# Out:
# -3.0 -1.5
# -1.5 -3.0
# 0.0 0.0
# 1.5 -0.6
# 3.0 -0.75

# %% [markdown]
# <h1>Hello World!</h1>

# %%
sym.Derivative()

# %%
len(x_values)
# Out:
# 500

# %%
plt.plot(x_values, fsl(x_values))

# %%
sym.limit(fs, x, 0, dir="+")
# Out:
# 0

# %% [markdown]
# ## Task 2:
# <p><ul>
# <li> Find another rational function $g(x)$ such that <br> $\lim_{x \to 0^{+}} g(x) = \infty$ </li>
# <li> Show that the limit is infinity (by making a table of values) and using sympy.limit</li>
# <li> Draw the graph of the function in the interval $[-3,3]$ </li></ul></p>

# %%
gs = sym.sympify("x/x**2")
gsl = sym.lambdify(x, gs)
x_values = np.linspace(-3, 3, 100)
y_values = gsl(x_values)

# %%
plt.plot(x_values, y_values)

# %%
sym.limit(gs, x, 0, dir="+")
# Out:
# oo

# %% [markdown]
# ## Task 3:
# <p>Now evaluate the limit (by making table of values and drawing the graph) and using sympy.limit<br> $\lim_{x \to 0^{+}} {(1+f(x))}^{g(x)}$</p>

# %%
hs = (1 + fs) ** gs 
hsl = sym.lambdify(x, hs)
x_values = np.linspace(-3, 3, 100)
y_values = hsl(x_values)
# Out:
# <lambdifygenerated-10>:2: RuntimeWarning: divide by zero encountered in reciprocal
#   return ((x + 1)**(-1.0))**(x**(-1.0))
# <lambdifygenerated-10>:2: RuntimeWarning: invalid value encountered in power
#   return ((x + 1)**(-1.0))**(x**(-1.0))

# %%
plt.plot(x_values, y_values)

# %%
sym.limit(hs, x, 0, dir="+")
# Out:
# exp(-1)

# %% [markdown]
# ## Task 4:
# <p>Evaluate the following expression (by making table of values) and using sympy.limit:<br> $e^{\lim_{x \to 0^{+}} {f(x) \cdot g(x)}}$

# %%
ms = sym.exp(fs * gs)
msl = sym.lambdify(x, ms)
x_values = np.linspace(-3, 3, 100)
y_values = msl(x_values)
# Out:
# <lambdifygenerated-12>:2: RuntimeWarning: divide by zero encountered in reciprocal
#   return exp((-1 + (x + 1)**(-1.0))/x)

# %%
plt.plot(x_values, y_values)

# %%
sym.limit(ms, x, 0, dir="+")
# Out:
# exp(-1)

# %% [markdown]
# ## Task 5
# <p> What do you think? Are these two expressions in Task3 and Task 4 equal? Explain briefly.</p>

# %%
#they are not equal because they have different values and different graphs
